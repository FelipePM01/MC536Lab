# %% [markdown]
# # Lab 1 - API de Acesso a Dados

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import requests
url = "http://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=gene&id=2&retmode=xml"
data = requests.get(url).content
print(data.decode("utf-8"))
# Out:
# <?xml version="1.0" ?>
# <!DOCTYPE Entrezgene-Set PUBLIC "-//NLM//DTD NCBI-Entrezgene, 21st January 2005//EN" "https://www.ncbi.nlm.nih.gov/data_specs/dtd/NCBI_Entrezgene.dtd">
# <Entrezgene-Set>
# <Entrezgene>
#   <Entrezgene_track-info>
#     <Gene-track>
#       <Gene-track_geneid>2</Gene-track_geneid>
#       <Gene-track_status value="live">0</Gene-track_status>
#       <Gene-track_create-date>
#         <Date>
#           <Date_std>
#             <Date-std>
#               <Date-std_year>1998</Date-std_year>
#               <Date-std_month>12</Date-std_month>
#               <Date-std_day>2</Date-std_day>
#             </Date-std>
#           </Date_std>
#         </Date>
#       </Gene-track_create-date>
#       <Gene-track_update-date>
#         <Date>
#           <Date_std>
#             <Date-std>
#               <Date-std_year>2021</Date-std_year>
#               <Date-std_month>7</Date-std_month>
#               <Date-std_day>11</Date-std_day>
#             </Date-std>
# ...

# %%
import io
import requests
import json
url = "https://www.proteinatlas.org/ENSG00000134057.json"
js = requests.get(url).content
print(js.decode("utf-8"))
# Out:
# {"Gene":"CCNB1","Gene synonym":["CCNB"],"Ensembl":"ENSG00000134057","Gene description":"Cyclin B1","Uniprot":["P14635"],"Chromosome":"5","Position":"69167010-69178245","Protein class":["Cancer-related genes","Plasma proteins","Predicted intracellular proteins","Transporters"],"Biological process":["Cell cycle","Cell division","Mitosis"],"Molecular function":["Cyclin"],"Disease involvement":["Cancer-related genes"],"Evidence":"Evidence at protein level","HPA evidence":"Evidence at protein level","UniProt evidence":"Evidence at protein level","NeXtProt evidence":"Evidence at protein level","MS evidence":"Evidence at protein level","RNA tissue specificity":"Tissue enhanced","RNA tissue distribution":"Detected in all","RNA tissue specificity score":null,"RNA tissue specific NX":{"lymphoid tissue":"71.4"},"RNA single cell type specificity":"Cell type enriched","RNA single cell type distribution":"Detected in many","RNA single cell type specificity score":"9","RNA single cell type specific
# ...

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.
